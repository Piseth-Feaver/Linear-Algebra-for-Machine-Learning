# %% [markdown]
# **How to use norm in numpy?**

# %%
from numpy import array
from numpy.linalg import norm
a = array([1, 2, 3])
print(a)
l1 = norm(a, 1)
print(l1)
# Out:
# [1 2 3]
# 6.0

# %%
from numpy import array
from numpy.linalg import norm
a = array([1, 2, 3])
l1 = norm(a, 2)
print(l1)
# Out:
# 3.7416573867739413

# %%
from numpy import array
from numpy.linalg import norm
a = array([1, 2, 3])
l2 = norm(a)
print(l2)
# Out:
# 3.7416573867739413

# %%
# Care about the value that is bigger
from math import inf
from numpy import array
from numpy.linalg import norm
a = array([-1, -7, -3])
maximum = max(a)
print(maximum)
# Out:
# -1

# %%
# Don't care about the sign of the value buz it is absolute value
from math import inf
from numpy import array
from numpy.linalg import norm

maximum = norm(a,inf)
print(maximum)
# Out:
# [-7 -1 -9]
# 9.0
